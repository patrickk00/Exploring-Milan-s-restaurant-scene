# %%
import pandas as pd
import ast

df = pd.read_csv('../output/google_places_no_duplicates.csv')

# %% [markdown]
# # Data Cleaning
# here the columns:
# business_status
# geometry
# icon
# icon_background_color
# icon_mask_base_uri
# name
# opening_hours
# photos
# place_id
# plus_code
# price_level
# rating
# reference
# scope
# types
# user_ratings_total
# vicinity
# permanently_closed

# %% [markdown]
# Step 1. merge permanentrly_closed column (boolean) into business_status (string)

# %%
df.loc[df['permanently_closed'] == True, 'business_status'] = 'PERMANENTLY_CLOSED' 
df = df.drop(columns=['permanently_closed'])

# %%
df = df[df['business_status'] != 'PERMANENTLY_CLOSED']
df = df[df['vicinity'].str.contains(', Milano|Italy')]
df
# Out:
#       Index business_status  \
# 11       16     OPERATIONAL
# 24       59     OPERATIONAL
# 25       60     OPERATIONAL
# 28      116     OPERATIONAL
# 37      135     OPERATIONAL
# ...     ...             ...
# 8437  36971     OPERATIONAL
# 8442  37001     OPERATIONAL
# 8487  37206     OPERATIONAL
# 8488  37210     OPERATIONAL
# 8496  37252     OPERATIONAL
#
#                                                geometry  \
# 11    {'location': {'lat': 45.4028435, 'lng': 9.1523...
# 24    {'location': {'lat': 45.4039192, 'lng': 9.1724...
# 25    {'location': {'lat': 45.4040433, 'lng': 9.1723...
# 28    {'location': {'lat': 45.404514, 'lng': 9.17414...
# 37    {'location': {'lat': 45.4050454, 'lng': 9.1527...
# ...                                                 ...
# 8437  {'location': {'lat': 45.531519, 'lng': 9.22308...
# 8442  {'location': {'lat': 45.5315587, 'lng': 9.2349...
# 8487  {'location': {'lat': 45.53279850000001, 'lng':...
# 8488  {'location': {'lat': 45.5328836, 'lng': 9.2257...
# 8496  {'location': {'lat': 45.5335226, 'lng': 9.2309...
#
#                                                    icon icon_background_color  \
# 11    https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 24    https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 25    https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 28    https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 37    https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# ...                                                 ...                   ...
# 8437  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8442  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8487  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8488  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8496  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
#                                      icon_mask_base_uri  \
# 11    https://maps.gstatic.com/mapfiles/place_api/ic...
# 24    https://maps.gstatic.com/mapfiles/place_api/ic...
# 25    https://maps.gstatic.com/mapfiles/place_api/ic...
# 28    https://maps.gstatic.com/mapfiles/place_api/ic...
# 37    https://maps.gstatic.com/mapfiles/place_api/ic...
# ...                                                 ...
# 8437  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8442  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8487  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8488  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8496  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                    name  \
# 11                        Panino Giusto
# 24                     Pizzeria Il Molo
# 25    Pizzeria Da Kiro Pizza da asporto
# 28        Antica Osteria Il Ronchettino
# 37                   Sushi Daily Assago
# ...                                 ...
# 8437                   la olla de barro
# 8442                   Panino Teca Cafè
# 8487                       Ladies' Cafe
# 8488                         Lady Pizza
# 8496           Ristorante La cittadella
#
#                                                  photos  \
# 11    [{'height': 3024, 'html_attributions': ['<a hr...
# 24    [{'height': 4032, 'html_attributions': ['<a hr...
# 25    [{'height': 4032, 'html_attributions': ['<a hr...
# 28    [{'height': 2736, 'html_attributions': ['<a hr...
# 37    [{'height': 1276, 'html_attributions': ['<a hr...
# ...                                                 ...
# 8437  [{'height': 545, 'html_attributions': ['<a hre...
# 8442                                                NaN
# 8487  [{'height': 1528, 'html_attributions': ['<a hr...
# 8488  [{'height': 5312, 'html_attributions': ['<a hr...
# 8496                                                NaN
#
#                          place_id  \
# 11    ChIJU5P6SHjDhkcR3r3uHXajH1M
# 24    ChIJ13yD6ZjEhkcRqupBIvl6VSo
# 25    ChIJcS-p8ZjEhkcRRFjuY9Kx4f8
# 28    ChIJZexKQpjEhkcRSKnOqLVEEOU
# 37    ChIJN9z2447DhkcROxmg2dU22Cg
# ...                           ...
# 8437  ChIJJ5Ow_QXHhkcRbu6bcMluSsM
# 8442  ChIJUbgl3p24hkcRIRvbXrGqvgU
# 8487  ChIJ3ffKNqe4hkcRWTW16PnU1cc
# 8488  ChIJVZKB-qC4hkcRJlDBko8zBwY
# 8496  ChIJG2i1O6q5hkcRnXCk1UjGWuo
#
#                                               plus_code  \
# 11    {'compound_code': 'C532+4W Milan, Metropolitan...
# 24    {'compound_code': 'C53C+HX Milan, Metropolitan...
# 25    {'compound_code': 'C53C+JW Milan, Metropolitan...
# 28    {'compound_code': 'C53F+RM Milan, Metropolitan...
# 37    {'compound_code': 'C543+24 Milan, Metropolitan...
# ...                                                 ...
# 8437  {'compound_code': 'G6JF+J6 Milan, Metropolitan...
# 8442  {'compound_code': 'G6JM+JX Sesto San Giovanni,...
# 8487  {'compound_code': 'G6MF+45 Sesto San Giovanni,...
# 8488  {'compound_code': 'G6MG+58 Sesto San Giovanni,...
# 8496  {'compound_code': 'G6MJ+C9 Milan, Metropolitan...
#
#                         reference   scope  \
# 11    ChIJU5P6SHjDhkcR3r3uHXajH1M  GOOGLE
# 24    ChIJ13yD6ZjEhkcRqupBIvl6VSo  GOOGLE
# 25    ChIJcS-p8ZjEhkcRRFjuY9Kx4f8  GOOGLE
# 28    ChIJZexKQpjEhkcRSKnOqLVEEOU  GOOGLE
# 37    ChIJN9z2447DhkcROxmg2dU22Cg  GOOGLE
# ...                           ...     ...
# 8437  ChIJJ5Ow_QXHhkcRbu6bcMluSsM  GOOGLE
# 8442  ChIJUbgl3p24hkcRIRvbXrGqvgU  GOOGLE
# 8487  ChIJ3ffKNqe4hkcRWTW16PnU1cc  GOOGLE
# 8488  ChIJVZKB-qC4hkcRJlDBko8zBwY  GOOGLE
# 8496  ChIJG2i1O6q5hkcRnXCk1UjGWuo  GOOGLE
#
#                                                   types  \
# 11    ['restaurant', 'food', 'point_of_interest', 'e...
# 24    ['meal_takeaway', 'restaurant', 'food', 'point...
# 25    ['meal_delivery', 'restaurant', 'food', 'point...
# 28    ['restaurant', 'point_of_interest', 'food', 'e...
# 37    ['meal_takeaway', 'restaurant', 'food', 'point...
# ...                                                 ...
# 8437  ['cafe', 'restaurant', 'food', 'store', 'point...
# 8442  ['restaurant', 'food', 'point_of_interest', 'e...
# 8487  ['restaurant', 'food', 'point_of_interest', 'e...
# 8488  ['restaurant', 'point_of_interest', 'food', 'e...
# 8496  ['restaurant', 'food', 'point_of_interest', 'e...
#
#                                                vicinity        opening_hours  \
# 11         CC Carrefour, Viale Milano Fiori, 23, Milano  {'open_now': False}
# 24                   Via Costantino Baroni, 244, Milano   {'open_now': True}
# 25                   Via Costantino Baroni, 242, Milano   {'open_now': True}
# 28                           Via Lelio Basso, 9, Milano  {'open_now': False}
# 37    Milanofiori Centro Commerciale, Viale Milanofi...   {'open_now': True}
# ...                                                 ...                  ...
# 8437          via marconi 238 sesto san giovani, Milano  {'open_now': False}
# 8442                                              Italy                  NaN
# 8487                                              Italy                  NaN
# 8488                                              Italy  {'open_now': False}
# 8496                                   Via Roma, Milano                  NaN
#
#       rating  user_ratings_total  price_level
# 11       3.8               438.0          2.0
# 24       4.0               130.0          1.0
# 25       3.9                47.0          1.0
# 28       4.3              1232.0          2.0
# 37       4.1                 7.0          NaN
# ...      ...                 ...          ...
# 8437     3.7               169.0          2.0
# 8442     NaN                 NaN          NaN
# 8487     4.8                22.0          NaN
# 8488     4.3                46.0          1.0
# 8496     NaN                 NaN          NaN
#
# [6605 rows x 18 columns]

# %% [markdown]
# Step 2. Adjust Geometry field according to what we need

# %%
df['geometry'] = df['geometry'].apply(lambda x: ast.literal_eval(x)['location'])
df['geometry']
# Out:
# 11      {'lat': 45.4028435, 'lng': 9.152347899999999}
# 24              {'lat': 45.4039192, 'lng': 9.1724335}
# 25              {'lat': 45.4040433, 'lng': 9.1723005}
# 28                {'lat': 45.404514, 'lng': 9.174146}
# 37      {'lat': 45.4050454, 'lng': 9.152785100000001}
#                             ...
# 8437             {'lat': 45.531519, 'lng': 9.2230804}
# 8442    {'lat': 45.5315587, 'lng': 9.234912099999999}
# 8487     {'lat': 45.53279850000001, 'lng': 9.2229361}
# 8488            {'lat': 45.5328836, 'lng': 9.2257845}
# 8496            {'lat': 45.5335226, 'lng': 9.2309928}
# Name: geometry, Length: 6605, dtype: object

# %%
df = df.drop(columns=['icon','icon_background_color','icon_background_color','icon_mask_base_uri', 'opening_hours', 'photos', 'plus_code', 'reference', 'scope'])
df
# Out:
#       Index business_status                                       geometry  \
# 11       16     OPERATIONAL  {'lat': 45.4028435, 'lng': 9.152347899999999}
# 24       59     OPERATIONAL          {'lat': 45.4039192, 'lng': 9.1724335}
# 25       60     OPERATIONAL          {'lat': 45.4040433, 'lng': 9.1723005}
# 28      116     OPERATIONAL            {'lat': 45.404514, 'lng': 9.174146}
# 37      135     OPERATIONAL  {'lat': 45.4050454, 'lng': 9.152785100000001}
# ...     ...             ...                                            ...
# 8437  36971     OPERATIONAL           {'lat': 45.531519, 'lng': 9.2230804}
# 8442  37001     OPERATIONAL  {'lat': 45.5315587, 'lng': 9.234912099999999}
# 8487  37206     OPERATIONAL   {'lat': 45.53279850000001, 'lng': 9.2229361}
# 8488  37210     OPERATIONAL          {'lat': 45.5328836, 'lng': 9.2257845}
# 8496  37252     OPERATIONAL          {'lat': 45.5335226, 'lng': 9.2309928}
#
#                                    name                     place_id  \
# 11                        Panino Giusto  ChIJU5P6SHjDhkcR3r3uHXajH1M
# 24                     Pizzeria Il Molo  ChIJ13yD6ZjEhkcRqupBIvl6VSo
# 25    Pizzeria Da Kiro Pizza da asporto  ChIJcS-p8ZjEhkcRRFjuY9Kx4f8
# 28        Antica Osteria Il Ronchettino  ChIJZexKQpjEhkcRSKnOqLVEEOU
# 37                   Sushi Daily Assago  ChIJN9z2447DhkcROxmg2dU22Cg
# ...                                 ...                          ...
# 8437                   la olla de barro  ChIJJ5Ow_QXHhkcRbu6bcMluSsM
# 8442                   Panino Teca Cafè  ChIJUbgl3p24hkcRIRvbXrGqvgU
# 8487                       Ladies' Cafe  ChIJ3ffKNqe4hkcRWTW16PnU1cc
# 8488                         Lady Pizza  ChIJVZKB-qC4hkcRJlDBko8zBwY
# 8496           Ristorante La cittadella  ChIJG2i1O6q5hkcRnXCk1UjGWuo
#
#                                                   types  \
# 11    ['restaurant', 'food', 'point_of_interest', 'e...
# 24    ['meal_takeaway', 'restaurant', 'food', 'point...
# 25    ['meal_delivery', 'restaurant', 'food', 'point...
# 28    ['restaurant', 'point_of_interest', 'food', 'e...
# 37    ['meal_takeaway', 'restaurant', 'food', 'point...
# ...                                                 ...
# 8437  ['cafe', 'restaurant', 'food', 'store', 'point...
# 8442  ['restaurant', 'food', 'point_of_interest', 'e...
# 8487  ['restaurant', 'food', 'point_of_interest', 'e...
# 8488  ['restaurant', 'point_of_interest', 'food', 'e...
# 8496  ['restaurant', 'food', 'point_of_interest', 'e...
#
#                                                vicinity  rating  \
# 11         CC Carrefour, Viale Milano Fiori, 23, Milano     3.8
# 24                   Via Costantino Baroni, 244, Milano     4.0
# 25                   Via Costantino Baroni, 242, Milano     3.9
# 28                           Via Lelio Basso, 9, Milano     4.3
# 37    Milanofiori Centro Commerciale, Viale Milanofi...     4.1
# ...                                                 ...     ...
# 8437          via marconi 238 sesto san giovani, Milano     3.7
# 8442                                              Italy     NaN
# 8487                                              Italy     4.8
# 8488                                              Italy     4.3
# 8496                                   Via Roma, Milano     NaN
#
#       user_ratings_total  price_level
# 11                 438.0          2.0
# 24                 130.0          1.0
# 25                  47.0          1.0
# 28                1232.0          2.0
# 37                   7.0          NaN
# ...                  ...          ...
# 8437               169.0          2.0
# 8442                 NaN          NaN
# 8487                22.0          NaN
# 8488                46.0          1.0
# 8496                 NaN          NaN
#
# [6605 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# Index                    0
# business_status          0
# geometry                 0
# name                     0
# place_id                 0
# types                    0
# vicinity                 0
# rating                 469
# user_ratings_total     469
# price_level           3429
# dtype: int64

# %%
# Check if there are some restaurants with the same name
df_grouped = df.groupby('name').size().reset_index(name='counts')
result = df_grouped[df_grouped['counts'] > 1]
result.to_csv('../output/duplicates_name.csv')

# %%
new_col_names = {'price_level': 'price_level_g',
                'rating': 'rating_g',
                'user_ratings_total': 'total_reviews_g',
                'price_level': 'price_level_g',
                'vicinity': 'address_g',
                'name': 'name_g'}
df = df.rename(columns=new_col_names)
df
# Out:
#       Index business_status                                       geometry  \
# 11       16     OPERATIONAL  {'lat': 45.4028435, 'lng': 9.152347899999999}
# 24       59     OPERATIONAL          {'lat': 45.4039192, 'lng': 9.1724335}
# 25       60     OPERATIONAL          {'lat': 45.4040433, 'lng': 9.1723005}
# 28      116     OPERATIONAL            {'lat': 45.404514, 'lng': 9.174146}
# 37      135     OPERATIONAL  {'lat': 45.4050454, 'lng': 9.152785100000001}
# ...     ...             ...                                            ...
# 8437  36971     OPERATIONAL           {'lat': 45.531519, 'lng': 9.2230804}
# 8442  37001     OPERATIONAL  {'lat': 45.5315587, 'lng': 9.234912099999999}
# 8487  37206     OPERATIONAL   {'lat': 45.53279850000001, 'lng': 9.2229361}
# 8488  37210     OPERATIONAL          {'lat': 45.5328836, 'lng': 9.2257845}
# 8496  37252     OPERATIONAL          {'lat': 45.5335226, 'lng': 9.2309928}
#
#                                  name_g                     place_id  \
# 11                        Panino Giusto  ChIJU5P6SHjDhkcR3r3uHXajH1M
# 24                     Pizzeria Il Molo  ChIJ13yD6ZjEhkcRqupBIvl6VSo
# 25    Pizzeria Da Kiro Pizza da asporto  ChIJcS-p8ZjEhkcRRFjuY9Kx4f8
# 28        Antica Osteria Il Ronchettino  ChIJZexKQpjEhkcRSKnOqLVEEOU
# 37                   Sushi Daily Assago  ChIJN9z2447DhkcROxmg2dU22Cg
# ...                                 ...                          ...
# 8437                   la olla de barro  ChIJJ5Ow_QXHhkcRbu6bcMluSsM
# 8442                   Panino Teca Cafè  ChIJUbgl3p24hkcRIRvbXrGqvgU
# 8487                       Ladies' Cafe  ChIJ3ffKNqe4hkcRWTW16PnU1cc
# 8488                         Lady Pizza  ChIJVZKB-qC4hkcRJlDBko8zBwY
# 8496           Ristorante La cittadella  ChIJG2i1O6q5hkcRnXCk1UjGWuo
#
#                                                   types  \
# 11    ['restaurant', 'food', 'point_of_interest', 'e...
# 24    ['meal_takeaway', 'restaurant', 'food', 'point...
# 25    ['meal_delivery', 'restaurant', 'food', 'point...
# 28    ['restaurant', 'point_of_interest', 'food', 'e...
# 37    ['meal_takeaway', 'restaurant', 'food', 'point...
# ...                                                 ...
# 8437  ['cafe', 'restaurant', 'food', 'store', 'point...
# 8442  ['restaurant', 'food', 'point_of_interest', 'e...
# 8487  ['restaurant', 'food', 'point_of_interest', 'e...
# 8488  ['restaurant', 'point_of_interest', 'food', 'e...
# 8496  ['restaurant', 'food', 'point_of_interest', 'e...
#
#                                               address_g  rating_g  \
# 11         CC Carrefour, Viale Milano Fiori, 23, Milano       3.8
# 24                   Via Costantino Baroni, 244, Milano       4.0
# 25                   Via Costantino Baroni, 242, Milano       3.9
# 28                           Via Lelio Basso, 9, Milano       4.3
# 37    Milanofiori Centro Commerciale, Viale Milanofi...       4.1
# ...                                                 ...       ...
# 8437          via marconi 238 sesto san giovani, Milano       3.7
# 8442                                              Italy       NaN
# 8487                                              Italy       4.8
# 8488                                              Italy       4.3
# 8496                                   Via Roma, Milano       NaN
#
#       total_reviews_g  price_level_g
# 11              438.0            2.0
# 24              130.0            1.0
# 25               47.0            1.0
# 28             1232.0            2.0
# 37                7.0            NaN
# ...               ...            ...
# 8437            169.0            2.0
# 8442              NaN            NaN
# 8487             22.0            NaN
# 8488             46.0            1.0
# 8496              NaN            NaN
#
# [6605 rows x 10 columns]

# %%
df.groupby("name_g").count() > 1
# Out:
#                                         Index  business_status  geometry  \
# name_g
# "DAVET " TURKISH -KEBAP PIZZERIA-GRILL  False            False     False
# "Woodstock dal 1969”                    False            False     False
# 'A Storia                               False            False     False
# 'Gnulot, Pasta Fresca                   False            False     False
# 'O Fiore Mio Pizze di Strada            False            False     False
# ...                                       ...              ...       ...
# 西安 Xi'an·Loreto                         False            False     False
# 郑记小吃                                    False            False     False
# 韩菜店                                     False            False     False
# 미가 MIGA Ristorante Coreano              False            False     False
# 프라텔리 식당                                 False            False     False
#
#                                         place_id  types  address_g  rating_g  \
# name_g
# "DAVET " TURKISH -KEBAP PIZZERIA-GRILL     False  False      False     False
# "Woodstock dal 1969”                       False  False      False     False
# 'A Storia                                  False  False      False     False
# 'Gnulot, Pasta Fresca                      False  False      False     False
# 'O Fiore Mio Pizze di Strada               False  False      False     False
# ...                                          ...    ...        ...       ...
# 西安 Xi'an·Loreto                            False  False      False     False
# 郑记小吃                                       False  False      False     False
# 韩菜店                                        False  False      False     False
# 미가 MIGA Ristorante Coreano                 False  False      False     False
# 프라텔리 식당                                    False  False      False     False
#
#                                         total_reviews_g  price_level_g
# name_g
# "DAVET " TURKISH -KEBAP PIZZERIA-GRILL            False          False
# "Woodstock dal 1969”                              False          False
# 'A Storia                                         False          False
# 'Gnulot, Pasta Fresca                             False          False
# 'O Fiore Mio Pizze di Strada                      False          False
# ...                                                 ...            ...
# 西安 Xi'an·Loreto                                   False          False
# 郑记小吃                                              False          False
# 韩菜店                                               False          False
# 미가 MIGA Ristorante Coreano                        False          False
# 프라텔리 식당                                           False          False
#
# [6232 rows x 9 columns]

# %%
df.to_csv('../output/google_places_cleaned.csv')
