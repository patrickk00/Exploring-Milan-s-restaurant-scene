# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path1 = "../integration/not_found_trip.xlsx"
file_path2 = "../integration/integration_definitive.xlsx"

not_found_trip = pd.read_excel(file_path1)
integration_definitive = pd.read_excel(file_path2)

# %%
integration_definitive
# Out:
#       id_trip                            name_trip  rating_trip
# 0           0                   Mabuhay Restaurant          5.0  \
# 1           1                        Parea Bistrot          5.0
# 2           2                            Il Panino          5.0
# 3           3                 Cantiere Hambirreria          5.0
# 4           4  BLUE M Milano - Bottega Marchigiana          5.0
# ...       ...                                  ...          ...
# 3595     6959      D'sumare Restaurante & Polleria          NaN
# 3596     6960            Radhuni Indian Restaurant          NaN
# 3597     6961                      Cleopatra Pizza          NaN
# 3598     6963   Davet Turkish Kebap Pizzeria Grill          NaN
# 3599     6967                               Hekfan          NaN
#
#       total_reviews_trip             cook_type_trip price_level_trip
# 0                    842                  Filippina                1  \
# 1                    158                          ?                ?
# 2                    226   Italiana, Cibo di strada                1
# 3                    923        Italiana, Americana                ?
# 4                    158                   Italiana                1
# ...                  ...                        ...              ...
# 3595                   0  Peruviana, Cibo di strada                ?
# 3596                   0         Indiana, Fast food                ?
# 3597                   0           Pizza, Fast food                ?
# 3598                   0           Pizza, Fast food                ?
# 3599                   0                          ?                ?
#
#                                            address_trip
# 0        Bastioni di Porta Volta 9, 20121 Milano Italia  \
# 1                      Via Vigna 6, 20123 Milano Italia
# 2                   Via Laghetto 7, 20122 Milano Italia
# 3             Corso Garibaldi, 111, 20121 Milano Italia
# 4     Via Lanzone 27 Sant'Ambrogio - Università Catt...
# ...                                                 ...
# 3595                 Via Padova 31, 20127 Milano Italia
# 3596    Via Predabissi angolo via Padova, Milano Italia
# 3597                Via Padova, 29, 20127 Milano Italia
# 3598   Piazzale Stazione Genova, 2, 20144 Milano Italia
# 3599             Via Marco Formentini, 2, Milano Italia
#
#                                                 reviews
# 0     [{'bubbles': 'bubble_50', 'title': 'Piacevole ...  \
# 1     [{'bubbles': 'bubble_50', 'title': 'Locale sex...
# 2     [{'bubbles': 'bubble_50', 'title': 'Da brevett...
# 3     [{'bubbles': 'bubble_50', 'title': 'SUPER!', '...
# 4     [{'bubbles': 'bubble_50', 'title': 'Le Marche ...
# ...                                                 ...
# 3595                                                 []
# 3596                                                 []
# 3597                                                 []
# 3598                                                 []
# 3599                                                 []
#
#           formatted_name_trip                       formatted_address_trip
# 0                     mabuhay                        bastionidiportavolta9  \
# 1                       parea                                    viavigna6
# 2                    ilpanino                                 vialaghetto7
# 3         cantierehambirreria                            corsogaribaldi111
# 4     bluembottegamarchigiana  vialanzone27santambrogiouniversitàcattolica
# ...                       ...                                          ...
# 3595         dsumareepolleria                                  viapadova31
# 3596            radhuniindian     viapredabissiangoloviapadovamilanoitalia
# 3597           cleopatrapizza                                  viapadova29
# 3598             davetturkish                      piazzalestazionegenova2
# 3599                   hekfan              viamarcoformentini2milanoitalia
#
#       ...                                       geometry
# 0     ...          {'lat': 45.4793068, 'lng': 9.1821188}  \
# 1     ...  {'lat': 45.4641109, 'lng': 9.179431500000002}
# 2     ...          {'lat': 45.4615626, 'lng': 9.1956376}
# 3     ...  {'lat': 45.4787205, 'lng': 9.185232099999999}
# 4     ...   {'lat': 45.46062730000001, 'lng': 9.1765883}
# ...   ...                                            ...
# 3595  ...  {'lat': 45.4874793, 'lng': 9.218210700000002}
# 3596  ...  {'lat': 45.4909607, 'lng': 9.223432800000001}
# 3597  ...  {'lat': 45.4898432, 'lng': 9.221324300000001}
# 3598  ...   {'lat': 45.45380540000001, 'lng': 9.1700964}
# 3599  ...   {'lat': 45.47151089999999, 'lng': 9.1856077}
#
#                                       name_g                     place_id
# 0              MABUHAY! Ristorante Filippino  ChIJp1t0B3rBhkcRkhvz_gk4ARw  \
# 1                                      Parea  ChIJNaMlrjfBhkcReLHYJXwZdZU
# 2                     Il panino del laghetto  ChIJ-6W1E6bGhkcRR5BCiZUxEGg
# 3                Cantiere Hambirreria Milano  ChIJAT5Z3wjBhkcRr-dUFcAhgX4
# 4        BLUE M MILANO - BOTTEGA MARCHIGIANA  ChIJ_4UjHuXBhkcRQXJ5r5hdRHs
# ...                                      ...                          ...
# 3595                                D'sumare  ChIJeyYJ7-bGhkcR32WFx77-Al4
# 3596               Radhuni Indian Restaurant  ChIJoZRSKbzHhkcR21lB-b6HT4M
# 3597                         Cleopatra Pizza  ChIJEymO4ePGhkcR2Mx0NtAsQME
# 3598  "DAVET " TURKISH -KEBAP PIZZERIA-GRILL  ChIJN9AcT6LDhkcRPweDZ_3Hnqw
# 3599                                  Hekfan  ChIJSdADvyjBhkcRtfINDv7rGi4
#
#                                                   types
# 0     ['restaurant', 'food', 'point_of_interest', 'e...  \
# 1     ['restaurant', 'food', 'point_of_interest', 'e...
# 2     ['restaurant', 'food', 'point_of_interest', 'e...
# 3     ['restaurant', 'food', 'bar', 'point_of_intere...
# 4     ['restaurant', 'food', 'point_of_interest', 'e...
# ...                                                 ...
# 3595  ['restaurant', 'point_of_interest', 'food', 'e...
# 3596  ['restaurant', 'point_of_interest', 'food', 'e...
# 3597  ['restaurant', 'point_of_interest', 'food', 'e...
# 3598  ['restaurant', 'food', 'point_of_interest', 'e...
# 3599  ['restaurant', 'food', 'point_of_interest', 'e...
#
#                                 address_g rating_g total_reviews_g
# 0      Bastioni di Porta Volta, 9, Milano      4.8           880.0  \
# 1                    Via Vigna, 6, Milano      4.6            56.0
# 2                 Via Laghetto, 7, Milano      4.7           275.0
# 3            Corso Garibaldi, 111, Milano      4.2           630.0
# 4                 Via Lanzone, 27, Milano      4.7            92.0
# ...                                   ...      ...             ...
# 3595               Via Padova, 31, Milano      3.7          1289.0
# 3596                   Via Padova, Milano      2.9            16.0
# 3597               Via Padova, 29, Milano      3.8            34.0
# 3598  Piazzale Stazione Genova, 2, Milano      4.5           337.0
# 3599      Via Marco Formentini, 2, Milano      4.7            80.0
#
#      price_level_g         formatted_name_g      formatted_address_g
# 0              2.0         mabuhayfilippino    bastionidiportavolta9
# 1              NaN                    parea                viavigna6
# 2              1.0      ilpaninodellaghetto             vialaghetto7
# 3              2.0      cantierehambirreria        corsogaribaldi111
# 4              NaN  bluembottegamarchigiana             vialanzone27
# ...            ...                      ...                      ...
# 3595           NaN                  dsumare              viapadova31
# 3596           NaN            radhuniindian                viapadova
# 3597           NaN           cleopatrapizza              viapadova29
# 3598           1.0             davetturkish  piazzalestazionegenova2
# 3599           NaN                   hekfan      viamarcoformentini2
#
# [3600 rows x 23 columns]

# %%
not_found_trip
# Out:
#       id_trip                       name_trip  rating_trip
# 0          10            Kebabbar Star Zagros          5.0  \
# 1          21  Piadineria Artigianale Pascoli          4.0
# 2          25                Al Bacio Navigli          4.0
# 3          34                    Pizza Shambo          4.0
# 4          37               Wave Cocktail Bar          5.0
# ...       ...                             ...          ...
# 3366     6964        La Buttiga Franco's Room          NaN
# 3367     6965                          Nk Bar          NaN
# 3368     6966             Caffè Vergnano 1882          NaN
# 3369     6968         La Puccia Ignorante Xxl          NaN
# 3370     6969                Wine time milano          NaN
#
#       total_reviews_trip           cook_type_trip price_level_trip
# 0                    416     Mediorientale, Turca                1  \
# 1                    928      Italiana, Fast food                1
# 2                    163  Italiana, Contemporanea              2.5
# 3                    178          Pizza, Italiana              2.5
# 4                    351             Europea, Pub              2.5
# ...                  ...                      ...              ...
# 3366                   0      Italiana, Americana                ?
# 3367                   0                    Pizza                ?
# 3368                   0                        ?                ?
# 3369                   0      Italiana, Fast food                1
# 3370                   0                        ?                ?
#
#                                            address_trip
# 0                Corso 22 Marzo,38, 20135 Milano Italia  \
# 1          Via Niccolò Paganini, 2, 20131 Milano Italia
# 2                  Via Vigevano 32, 20144 Milano Italia
# 3                      Via Edolo 1, 20125 Milano Italia
# 4         Via Edmondo de Amicis 28, 20123 Milano Italia
# ...                                                 ...
# 3366           Via Castelbarco, 17, 20136 Milano Italia
# 3367        Via Giuseppe Saragat 6, 20128 Milano Italia
# 3368  Piazza Venticinque Aprile, 10 Eataly Smeraldo,...
# 3369    Via Filippo Brunelleschi 4, 20146 Milano Italia
# 3370                                                NaN
#
#                                                 reviews
# 0     [{'bubbles': 'bubble_50', 'title': 'Una piacev...  \
# 1     [{'bubbles': 'bubble_50', 'title': 'Piadine fr...
# 2     [{'bubbles': 'bubble_40', 'title': 'sosta velo...
# 3     [{'bubbles': 'bubble_30', 'title': 'Pizza a me...
# 4     [{'bubbles': 'bubble_10', 'title': 'Accoglienz...
# ...                                                 ...
# 3366                                                 []
# 3367                                                 []
# 3368                                                 []
# 3369                                                 []
# 3370                                                NaN
#
#                formatted_name_trip                   formatted_address_trip
# 0                       starzagros                           corso22marzo38
# 1     piadineriaartigianalepascoli                      vianiccolòpaganini2
# 2                   albacionavigli                            viavigevano32
# 3                      pizzashambo                                viaedolo1
# 4                     wavecocktail                     viaedmondodeamicis28
# ...                            ...                                      ...
# 3366          labuttigafrancosroom                         viacastelbarco17
# 3367                         nkbar                      viagiuseppesaragat6
# 3368             caffèvergnano1882  piazzaventicinqueaprile10eatalysmeraldo
# 3369          lapucciaignorantexxl                  viafilippobrunelleschi4
# 3370                      winetime                                    italy
#
# [3371 rows x 10 columns]

# %%
# Create a new column with unique labels
#integration_definitive['new_index'] = range(len(integration_definitive))

# Set place id as the index
integration_definitive = integration_definitive.set_index('place_id')

# %%
# remove ? char and put nan instead
integration_definitive= integration_definitive.replace('?', np.nan)
#convert to float
integration_definitive['price_level_trip'] = integration_definitive['price_level_trip'].astype(float)
integration_definitive['price_level_g'] = integration_definitive['price_level_g'].astype(float)

# %%
# Calculate rating weighting the trip rating and google rating on the total number reviews
has_rating_trip = ~integration_definitive['rating_trip'].isnull()
has_rating_g = ~integration_definitive['rating_g'].isnull()
has_both_ratings = has_rating_trip & has_rating_g

integration_definitive.loc[has_both_ratings, 'rating'] = ((integration_definitive.loc[has_both_ratings, 'rating_trip'] * integration_definitive.loc[has_both_ratings, 'total_reviews_trip'])
                                        + (integration_definitive.loc[has_both_ratings, 'rating_g'] * integration_definitive.loc[has_both_ratings, 'total_reviews_g'])) / (integration_definitive.loc[has_both_ratings, 'total_reviews_trip'] + integration_definitive.loc[has_both_ratings, 'total_reviews_g'])

# Calculate price_level weighting on total reviews
has_price_level_trip = ~integration_definitive['price_level_trip'].isnull()
has_price_level_g = ~integration_definitive['price_level_g'].isnull()

integration_definitive.loc[has_price_level_trip & has_price_level_g, 'price_level'] = ((integration_definitive.loc[has_price_level_trip & has_price_level_g, 'price_level_trip'] * integration_definitive.loc[has_price_level_trip & has_price_level_g, 'total_reviews_trip'])
                                                  + (integration_definitive.loc[has_price_level_trip & has_price_level_g, 'price_level_g'] *
                                                     integration_definitive.loc[has_price_level_trip & has_price_level_g, 'total_reviews_g'])) / (integration_definitive.loc[has_price_level_trip & has_price_level_g, 'total_reviews_trip'] + 
                                                                                                                               integration_definitive.loc[has_price_level_trip & has_price_level_g, 'total_reviews_g'])

integration_definitive.loc[has_price_level_trip & ~has_price_level_g, 'price_level'] = integration_definitive.loc[has_price_level_trip & ~has_price_level_g, 'price_level_trip']

integration_definitive.loc[~has_price_level_trip & has_price_level_g, 'price_level'] = integration_definitive.loc[~has_price_level_trip & has_price_level_g, 'price_level_g']

# Calculate total_reviews as sum of trip and google total reviews
integration_definitive['total_reviews'] = integration_definitive['total_reviews_g'].fillna(0) + integration_definitive['total_reviews_trip'].fillna(0)
integration_definitive
# Out:
#                              id_trip                            name_trip
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw        0                   Mabuhay Restaurant  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU        1                        Parea Bistrot
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg        2                            Il Panino
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4        3                 Cantiere Hambirreria
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs        4  BLUE M Milano - Bottega Marchigiana
# ...                              ...                                  ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4     6959      D'sumare Restaurante & Polleria
# ChIJoZRSKbzHhkcR21lB-b6HT4M     6960            Radhuni Indian Restaurant
# ChIJEymO4ePGhkcR2Mx0NtAsQME     6961                      Cleopatra Pizza
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw     6963   Davet Turkish Kebap Pizzeria Grill
# ChIJSdADvyjBhkcRtfINDv7rGi4     6967                               Hekfan
#
#                              rating_trip  total_reviews_trip
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw          5.0                 842  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU          5.0                 158
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg          5.0                 226
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4          5.0                 923
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs          5.0                 158
# ...                                  ...                 ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4          NaN                   0
# ChIJoZRSKbzHhkcR21lB-b6HT4M          NaN                   0
# ChIJEymO4ePGhkcR2Mx0NtAsQME          NaN                   0
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw          NaN                   0
# ChIJSdADvyjBhkcRtfINDv7rGi4          NaN                   0
#
#                                         cook_type_trip  price_level_trip
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw                  Filippina               1.0  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU                        NaN               NaN
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg   Italiana, Cibo di strada               1.0
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4        Italiana, Americana               NaN
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs                   Italiana               1.0
# ...                                                ...               ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4  Peruviana, Cibo di strada               NaN
# ChIJoZRSKbzHhkcR21lB-b6HT4M         Indiana, Fast food               NaN
# ChIJEymO4ePGhkcR2Mx0NtAsQME           Pizza, Fast food               NaN
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw           Pizza, Fast food               NaN
# ChIJSdADvyjBhkcRtfINDv7rGi4                        NaN               NaN
#
#                                                                   address_trip
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw     Bastioni di Porta Volta 9, 20121 Milano Italia  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU                   Via Vigna 6, 20123 Milano Italia
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg                Via Laghetto 7, 20122 Milano Italia
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4          Corso Garibaldi, 111, 20121 Milano Italia
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  Via Lanzone 27 Sant'Ambrogio - Università Catt...
# ...                                                                        ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4                 Via Padova 31, 20127 Milano Italia
# ChIJoZRSKbzHhkcR21lB-b6HT4M    Via Predabissi angolo via Padova, Milano Italia
# ChIJEymO4ePGhkcR2Mx0NtAsQME                Via Padova, 29, 20127 Milano Italia
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw   Piazzale Stazione Genova, 2, 20144 Milano Italia
# ChIJSdADvyjBhkcRtfINDv7rGi4             Via Marco Formentini, 2, Milano Italia
#
#                                                                        reviews
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw  [{'bubbles': 'bubble_50', 'title': 'Piacevole ...  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU  [{'bubbles': 'bubble_50', 'title': 'Locale sex...
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg  [{'bubbles': 'bubble_50', 'title': 'Da brevett...
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4  [{'bubbles': 'bubble_50', 'title': 'SUPER!', '...
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  [{'bubbles': 'bubble_50', 'title': 'Le Marche ...
# ...                                                                        ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4                                                 []
# ChIJoZRSKbzHhkcR21lB-b6HT4M                                                 []
# ChIJEymO4ePGhkcR2Mx0NtAsQME                                                 []
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw                                                 []
# ChIJSdADvyjBhkcRtfINDv7rGi4                                                 []
#
#                                  formatted_name_trip
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw                  mabuhay  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU                    parea
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg                 ilpanino
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4      cantierehambirreria
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  bluembottegamarchigiana
# ...                                              ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4         dsumareepolleria
# ChIJoZRSKbzHhkcR21lB-b6HT4M            radhuniindian
# ChIJEymO4ePGhkcR2Mx0NtAsQME           cleopatrapizza
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw             davetturkish
# ChIJSdADvyjBhkcRtfINDv7rGi4                   hekfan
#
#                                                   formatted_address_trip  ...
# place_id                                                                  ...
# ChIJp1t0B3rBhkcRkhvz_gk4ARw                        bastionidiportavolta9  ...  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU                                    viavigna6  ...
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg                                 vialaghetto7  ...
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4                            corsogaribaldi111  ...
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  vialanzone27santambrogiouniversitàcattolica  ...
# ...                                                                  ...  ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4                                  viapadova31  ...
# ChIJoZRSKbzHhkcR21lB-b6HT4M     viapredabissiangoloviapadovamilanoitalia  ...
# ChIJEymO4ePGhkcR2Mx0NtAsQME                                  viapadova29  ...
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw                      piazzalestazionegenova2  ...
# ChIJSdADvyjBhkcRtfINDv7rGi4              viamarcoformentini2milanoitalia  ...
#
#                                                                          types
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw  ['restaurant', 'food', 'point_of_interest', 'e...  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU  ['restaurant', 'food', 'point_of_interest', 'e...
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg  ['restaurant', 'food', 'point_of_interest', 'e...
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4  ['restaurant', 'food', 'bar', 'point_of_intere...
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  ['restaurant', 'food', 'point_of_interest', 'e...
# ...                                                                        ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4  ['restaurant', 'point_of_interest', 'food', 'e...
# ChIJoZRSKbzHhkcR21lB-b6HT4M  ['restaurant', 'point_of_interest', 'food', 'e...
# ChIJEymO4ePGhkcR2Mx0NtAsQME  ['restaurant', 'point_of_interest', 'food', 'e...
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw  ['restaurant', 'food', 'point_of_interest', 'e...
# ChIJSdADvyjBhkcRtfINDv7rGi4  ['restaurant', 'food', 'point_of_interest', 'e...
#
#                                                        address_g rating_g
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw   Bastioni di Porta Volta, 9, Milano      4.8  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU                 Via Vigna, 6, Milano      4.6
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg              Via Laghetto, 7, Milano      4.7
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4         Corso Garibaldi, 111, Milano      4.2
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs              Via Lanzone, 27, Milano      4.7
# ...                                                          ...      ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4               Via Padova, 31, Milano      3.7
# ChIJoZRSKbzHhkcR21lB-b6HT4M                   Via Padova, Milano      2.9
# ChIJEymO4ePGhkcR2Mx0NtAsQME               Via Padova, 29, Milano      3.8
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw  Piazzale Stazione Genova, 2, Milano      4.5
# ChIJSdADvyjBhkcRtfINDv7rGi4      Via Marco Formentini, 2, Milano      4.7
#
#                             total_reviews_g price_level_g
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw           880.0           2.0  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU            56.0           NaN
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg           275.0           1.0
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4           630.0           2.0
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs            92.0           NaN
# ...                                     ...           ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4          1289.0           NaN
# ChIJoZRSKbzHhkcR21lB-b6HT4M            16.0           NaN
# ChIJEymO4ePGhkcR2Mx0NtAsQME            34.0           NaN
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw           337.0           1.0
# ChIJSdADvyjBhkcRtfINDv7rGi4            80.0           NaN
#
#                                     formatted_name_g      formatted_address_g
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw         mabuhayfilippino    bastionidiportavolta9  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU                    parea                viavigna6
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg      ilpaninodellaghetto             vialaghetto7
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4      cantierehambirreria        corsogaribaldi111
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  bluembottegamarchigiana             vialanzone27
# ...                                              ...                      ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4                  dsumare              viapadova31
# ChIJoZRSKbzHhkcR21lB-b6HT4M            radhuniindian                viapadova
# ChIJEymO4ePGhkcR2Mx0NtAsQME           cleopatrapizza              viapadova29
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw             davetturkish  piazzalestazionegenova2
# ChIJSdADvyjBhkcRtfINDv7rGi4                   hekfan      viamarcoformentini2
#
#                                rating  price_level  total_reviews
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw  4.897793     1.511034         1722.0
# ChIJNaMlrjfBhkcReLHYJXwZdZU  4.895327          NaN          214.0
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg  4.835329     1.000000          501.0
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4  4.675467     2.000000         1553.0
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  4.889600     1.000000          250.0
# ...                               ...          ...            ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4       NaN          NaN         1289.0
# ChIJoZRSKbzHhkcR21lB-b6HT4M       NaN          NaN           16.0
# ChIJEymO4ePGhkcR2Mx0NtAsQME       NaN          NaN           34.0
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw       NaN     1.000000          337.0
# ChIJSdADvyjBhkcRtfINDv7rGi4       NaN          NaN           80.0
#
# [3600 rows x 25 columns]

# %%
#show null
integration_definitive.isna().sum()
# Out:
# id_trip                      0
# name_trip                    0
# rating_trip                246
# total_reviews_trip           0
# cook_type_trip             346
# price_level_trip           882
# address_trip                 1
# reviews                      0
# formatted_name_trip          0
# formatted_address_trip       1
# Unnamed: 0                   0
# Index                        0
# business_status              0
# geometry                     0
# name_g                       0
# types                        0
# address_g                    0
# rating_g                    22
# total_reviews_g             22
# price_level_g             1314
# formatted_name_g             0
# formatted_address_g          0
# rating                     259
# price_level                604
# total_reviews                0
# dtype: int64

# %%
import ast

#split lat and long
integration_definitive['geometry'] = integration_definitive['geometry'].apply(ast.literal_eval)

integration_definitive[['latitude']] = integration_definitive['geometry'][3]['lat']
integration_definitive[['longitude']] = integration_definitive['geometry'][3]['lng']

#take only useful fields. In order to avoid redaundancy we choose to keep just name and address of trip advisor
integration_definitive = integration_definitive[['name_trip','cook_type_trip','types','address_trip','latitude','longitude','rating','price_level','total_reviews','reviews']]
integration_definitive = integration_definitive.rename(columns={'name_trip': 'name', 'cook_type_trip': 'cook_type', 'address_trip': 'address'})

integration_definitive
# Out:
#                                                             name
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw                   Mabuhay Restaurant  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU                        Parea Bistrot
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg                            Il Panino
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4                 Cantiere Hambirreria
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  BLUE M Milano - Bottega Marchigiana
# ...                                                          ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4      D'sumare Restaurante & Polleria
# ChIJoZRSKbzHhkcR21lB-b6HT4M            Radhuni Indian Restaurant
# ChIJEymO4ePGhkcR2Mx0NtAsQME                      Cleopatra Pizza
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw   Davet Turkish Kebap Pizzeria Grill
# ChIJSdADvyjBhkcRtfINDv7rGi4                               Hekfan
#
#                                              cook_type
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw                  Filippina  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU                        NaN
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg   Italiana, Cibo di strada
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4        Italiana, Americana
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs                   Italiana
# ...                                                ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4  Peruviana, Cibo di strada
# ChIJoZRSKbzHhkcR21lB-b6HT4M         Indiana, Fast food
# ChIJEymO4ePGhkcR2Mx0NtAsQME           Pizza, Fast food
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw           Pizza, Fast food
# ChIJSdADvyjBhkcRtfINDv7rGi4                        NaN
#
#                                                                          types
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw  ['restaurant', 'food', 'point_of_interest', 'e...  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU  ['restaurant', 'food', 'point_of_interest', 'e...
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg  ['restaurant', 'food', 'point_of_interest', 'e...
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4  ['restaurant', 'food', 'bar', 'point_of_intere...
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  ['restaurant', 'food', 'point_of_interest', 'e...
# ...                                                                        ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4  ['restaurant', 'point_of_interest', 'food', 'e...
# ChIJoZRSKbzHhkcR21lB-b6HT4M  ['restaurant', 'point_of_interest', 'food', 'e...
# ChIJEymO4ePGhkcR2Mx0NtAsQME  ['restaurant', 'point_of_interest', 'food', 'e...
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw  ['restaurant', 'food', 'point_of_interest', 'e...
# ChIJSdADvyjBhkcRtfINDv7rGi4  ['restaurant', 'food', 'point_of_interest', 'e...
#
#                                                                        address
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw     Bastioni di Porta Volta 9, 20121 Milano Italia  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU                   Via Vigna 6, 20123 Milano Italia
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg                Via Laghetto 7, 20122 Milano Italia
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4          Corso Garibaldi, 111, 20121 Milano Italia
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  Via Lanzone 27 Sant'Ambrogio - Università Catt...
# ...                                                                        ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4                 Via Padova 31, 20127 Milano Italia
# ChIJoZRSKbzHhkcR21lB-b6HT4M    Via Predabissi angolo via Padova, Milano Italia
# ChIJEymO4ePGhkcR2Mx0NtAsQME                Via Padova, 29, 20127 Milano Italia
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw   Piazzale Stazione Genova, 2, 20144 Milano Italia
# ChIJSdADvyjBhkcRtfINDv7rGi4             Via Marco Formentini, 2, Milano Italia
#
#                               latitude  longitude    rating  price_level
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw  45.478721   9.185232  4.897793     1.511034  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU  45.478721   9.185232  4.895327          NaN
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg  45.478721   9.185232  4.835329     1.000000
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4  45.478721   9.185232  4.675467     2.000000
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  45.478721   9.185232  4.889600     1.000000
# ...                                ...        ...       ...          ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4  45.478721   9.185232       NaN          NaN
# ChIJoZRSKbzHhkcR21lB-b6HT4M  45.478721   9.185232       NaN          NaN
# ChIJEymO4ePGhkcR2Mx0NtAsQME  45.478721   9.185232       NaN          NaN
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw  45.478721   9.185232       NaN     1.000000
# ChIJSdADvyjBhkcRtfINDv7rGi4  45.478721   9.185232       NaN          NaN
#
#                              total_reviews
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw         1722.0  \
# ChIJNaMlrjfBhkcReLHYJXwZdZU          214.0
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg          501.0
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4         1553.0
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs          250.0
# ...                                    ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4         1289.0
# ChIJoZRSKbzHhkcR21lB-b6HT4M           16.0
# ChIJEymO4ePGhkcR2Mx0NtAsQME           34.0
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw          337.0
# ChIJSdADvyjBhkcRtfINDv7rGi4           80.0
#
#                                                                        reviews
# place_id
# ChIJp1t0B3rBhkcRkhvz_gk4ARw  [{'bubbles': 'bubble_50', 'title': 'Piacevole ...
# ChIJNaMlrjfBhkcReLHYJXwZdZU  [{'bubbles': 'bubble_50', 'title': 'Locale sex...
# ChIJ-6W1E6bGhkcRR5BCiZUxEGg  [{'bubbles': 'bubble_50', 'title': 'Da brevett...
# ChIJAT5Z3wjBhkcRr-dUFcAhgX4  [{'bubbles': 'bubble_50', 'title': 'SUPER!', '...
# ChIJ_4UjHuXBhkcRQXJ5r5hdRHs  [{'bubbles': 'bubble_50', 'title': 'Le Marche ...
# ...                                                                        ...
# ChIJeyYJ7-bGhkcR32WFx77-Al4                                                 []
# ChIJoZRSKbzHhkcR21lB-b6HT4M                                                 []
# ChIJEymO4ePGhkcR2Mx0NtAsQME                                                 []
# ChIJN9AcT6LDhkcRPweDZ_3Hnqw                                                 []
# ChIJSdADvyjBhkcRtfINDv7rGi4                                                 []
#
# [3600 rows x 10 columns]

# %%
integration_definitive.to_csv('./integration_cleaned_definitive.csv')
