# %%
import pandas as pd

df = pd.read_csv('../output_files/google_places_cleaned.csv')
# here the columns: 
# business_status	
# geometry	
# icon	
# icon_background_color	
# icon_mask_base_uri	
# name	opening_hours	
# photos	
# place_id	
# plus_code	
# price_level	
# rating	
# reference	
# scope	types	
# user_ratings_total	
# vicinity	
# permanently_closed

#merge permanentrly_closed column (boolean) into business_status

df.loc
