# %% [markdown]
# INTEGRATION

# %%
import pandas as pd

# %%
address_trip=pd.read_csv("C:/Users/pc/Desktop/progetti data management/data-management-project/output/reviews_save.csv")
address_trip
# Out:
#         id                                       address_trip  \
# 0        1                   Via Vigna 6, 20123 Milano Italia
# 1        0     Bastioni di Porta Volta 9, 20121 Milano Italia
# 2        3          Corso Garibaldi, 111, 20121 Milano Italia
# 3        2                Via Laghetto 7, 20122 Milano Italia
# 4        5  Via Novara, Piazza Carlo Amati, 31, 20147 Mila...
# ...    ...                                                ...
# 6964  6964           Via Castelbarco, 17, 20136 Milano Italia
# 6965  6965        Via Giuseppe Saragat 6, 20128 Milano Italia
# 6966  6966  Piazza Venticinque Aprile, 10 Eataly Smeraldo,...
# 6967  6967             Via Marco Formentini, 2, Milano Italia
# 6968  6968    Via Filippo Brunelleschi 4, 20146 Milano Italia
#
#                                                 reviews
# 0     [{'bubbles': 'bubble_50', 'title': 'Locale sex...
# 1     [{'bubbles': 'bubble_50', 'title': 'Piacevole ...
# 2     [{'bubbles': 'bubble_50', 'title': 'SUPER!', '...
# 3     [{'bubbles': 'bubble_50', 'title': 'Da brevett...
# 4     [{'bubbles': 'bubble_50', 'title': 'Ottima car...
# ...                                                 ...
# 6964                                                 []
# 6965                                                 []
# 6966                                                 []
# 6967                                                 []
# 6968                                                 []
#
# [6969 rows x 3 columns]

# %%
trip_advisor=pd.read_csv("C:/Users/pc/Desktop/progetti data management/data-management-project/output/trip_restaurants_final.csv")
trip_advisor['title'] = trip_advisor['title'].str.replace('^\d+\.\s', '')

trip_advisor
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_20436\2060783908.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   trip_advisor['title'] = trip_advisor['title'].str.replace('^\d+\.\s', '')
#         id                                title           r_bubbles  \
# 0        0                   Mabuhay Restaurant  Punteggio 5,0 su 5
# 1        1                        Parea Bistrot  Punteggio 5,0 su 5
# 2        2                            Il Panino  Punteggio 5,0 su 5
# 3        3                 Cantiere Hambirreria  Punteggio 5,0 su 5
# 4        4  BLUE M Milano - Bottega Marchigiana  Punteggio 5,0 su 5
# ...    ...                                  ...                 ...
# 6965  6965                               Nk Bar                   ?
# 6966  6966                  Caffè Vergnano 1882                   ?
# 6967  6967                               Hekfan                   ?
# 6968  6968              La Puccia Ignorante Xxl                   ?
# 6969  6969                     Wine time milano                   ?
#
#             r_number                 cook_type expensive
# 0     842 recensioni                 Filippina         €
# 1     158 recensioni                         ?         ?
# 2     226 recensioni  Italiana, Cibo di strada         €
# 3     923 recensioni       Italiana, Americana         ?
# 4     158 recensioni                  Italiana         €
# ...              ...                       ...       ...
# 6965               0                     Pizza         ?
# 6966               0                         ?         ?
# 6967               0                         ?         ?
# 6968               0       Italiana, Fast food         €
# 6969               0                         ?         ?
#
# [6970 rows x 6 columns]

# %%
trip_advisor
# Out:
#         id                                title           r_bubbles  \
# 0        0                   Mabuhay Restaurant  Punteggio 5,0 su 5
# 1        1                        Parea Bistrot  Punteggio 5,0 su 5
# 2        2                            Il Panino  Punteggio 5,0 su 5
# 3        3                 Cantiere Hambirreria  Punteggio 5,0 su 5
# 4        4  BLUE M Milano - Bottega Marchigiana  Punteggio 5,0 su 5
# ...    ...                                  ...                 ...
# 6965  6965                               Nk Bar                   ?
# 6966  6966                  Caffè Vergnano 1882                   ?
# 6967  6967                               Hekfan                   ?
# 6968  6968              La Puccia Ignorante Xxl                   ?
# 6969  6969                     Wine time milano                   ?
#
#             r_number                 cook_type expensive
# 0     842 recensioni                 Filippina         €
# 1     158 recensioni                         ?         ?
# 2     226 recensioni  Italiana, Cibo di strada         €
# 3     923 recensioni       Italiana, Americana         ?
# 4     158 recensioni                  Italiana         €
# ...              ...                       ...       ...
# 6965               0                     Pizza         ?
# 6966               0                         ?         ?
# 6967               0                         ?         ?
# 6968               0       Italiana, Fast food         €
# 6969               0                         ?         ?
#
# [6970 rows x 6 columns]

# %%
overall_trip=pd.merge(trip_advisor, address_trip , on="id")
overall_trip
# Out:
#         id                                title           r_bubbles  \
# 0        0                   Mabuhay Restaurant  Punteggio 5,0 su 5
# 1        1                        Parea Bistrot  Punteggio 5,0 su 5
# 2        2                            Il Panino  Punteggio 5,0 su 5
# 3        3                 Cantiere Hambirreria  Punteggio 5,0 su 5
# 4        4  BLUE M Milano - Bottega Marchigiana  Punteggio 5,0 su 5
# ...    ...                                  ...                 ...
# 6964  6964             La Buttiga Franco's Room                   ?
# 6965  6965                               Nk Bar                   ?
# 6966  6966                  Caffè Vergnano 1882                   ?
# 6967  6967                               Hekfan                   ?
# 6968  6968              La Puccia Ignorante Xxl                   ?
#
#             r_number                 cook_type expensive  \
# 0     842 recensioni                 Filippina         €
# 1     158 recensioni                         ?         ?
# 2     226 recensioni  Italiana, Cibo di strada         €
# 3     923 recensioni       Italiana, Americana         ?
# 4     158 recensioni                  Italiana         €
# ...              ...                       ...       ...
# 6964               0       Italiana, Americana         ?
# 6965               0                     Pizza         ?
# 6966               0                         ?         ?
# 6967               0                         ?         ?
# 6968               0       Italiana, Fast food         €
#
#                                            address_trip  \
# 0        Bastioni di Porta Volta 9, 20121 Milano Italia
# 1                      Via Vigna 6, 20123 Milano Italia
# 2                   Via Laghetto 7, 20122 Milano Italia
# 3             Corso Garibaldi, 111, 20121 Milano Italia
# 4     Via Lanzone 27 Sant'Ambrogio - Università Catt...
# ...                                                 ...
# 6964           Via Castelbarco, 17, 20136 Milano Italia
# 6965        Via Giuseppe Saragat 6, 20128 Milano Italia
# 6966  Piazza Venticinque Aprile, 10 Eataly Smeraldo,...
# 6967             Via Marco Formentini, 2, Milano Italia
# 6968    Via Filippo Brunelleschi 4, 20146 Milano Italia
#
#                                                 reviews
# 0     [{'bubbles': 'bubble_50', 'title': 'Piacevole ...
# 1     [{'bubbles': 'bubble_50', 'title': 'Locale sex...
# 2     [{'bubbles': 'bubble_50', 'title': 'Da brevett...
# 3     [{'bubbles': 'bubble_50', 'title': 'SUPER!', '...
# 4     [{'bubbles': 'bubble_50', 'title': 'Le Marche ...
# ...                                                 ...
# 6964                                                 []
# 6965                                                 []
# 6966                                                 []
# 6967                                                 []
# 6968                                                 []
#
# [6969 rows x 8 columns]

# %%
overall_trip[overall_trip["id"]==606]
# Out:
#       id                                   title           r_bubbles  \
# 605  606  Ham Holy Burger - Milano, viale Bligny  Punteggio 4,0 su 5
# 606  606  Ham Holy Burger - Milano, viale Bligny  Punteggio 4,0 su 5
#
#            r_number       cook_type expensive  \
# 605  704 recensioni  Americana, Bar  €€ - €€€
# 606  704 recensioni  Americana, Bar  €€ - €€€
#
#                              address_trip  \
# 605  Viale Bligny 39, 20136 Milano Italia
# 606  Viale Bligny 39, 20136 Milano Italia
#
#                                                reviews
# 605  [{'bubbles': 'bubble_50', 'title': 'Super appr...
# 606  [{'bubbles': 'bubble_50', 'title': 'Super appr...

# %%
overall_trip=overall_trip.drop_duplicates('id')
#there are 2 duplicates with the same id

# %%
overall_trip[overall_trip["id"]==606]
#check if i have removed the dubplicate
# Out:
#       id                                   title           r_bubbles  \
# 605  606  Ham Holy Burger - Milano, viale Bligny  Punteggio 4,0 su 5
#
#            r_number       cook_type expensive  \
# 605  704 recensioni  Americana, Bar  €€ - €€€
#
#                              address_trip  \
# 605  Viale Bligny 39, 20136 Milano Italia
#
#                                                reviews
# 605  [{'bubbles': 'bubble_50', 'title': 'Super appr...

# %%
google_dataset=pd.read_csv("C:/Users/pc/Desktop/progetti data management/data-management-project/output_files/google_dataset_cleaned_2.csv")
google_dataset=google_dataset[['Index', 'name_google','price_level_google','rating_google','total_reviews_google','address']]
google_dataset
# Out:
#       Index                     name_google  price_level_google  \
# 0         0                       Autogrill                 2.0
# 1         2        L'angolo del Buongustaio                 NaN
# 2         3     Compagnia Dell'Espresso Srl                 NaN
# 3         4                       Assago 03                 NaN
# 4         5                     Rasoi baget                 NaN
# ...     ...                             ...                 ...
# 6444  22590        Happy Moments Restaurant                 2.0
# 6445  22600    Bar Olimpia Di Gaeta Deborah                 NaN
# 6446  22605               Vinum Et Alia SPA                 NaN
# 6447  22607  Pizzeria Ristorante San Mina 2                 1.0
# 6448  22608                  Bar Buonarroti                 NaN
#
#       rating_google  total_reviews_google  \
# 0               3.5                2501.0
# 1               1.0                   1.0
# 2               NaN                   NaN
# 3               NaN                   NaN
# 4               NaN                   NaN
# ...             ...                   ...
# 6444            4.5                 826.0
# 6445            3.6                  54.0
# 6446            4.0                   2.0
# 6447            4.4                 125.0
# 6448            4.8                   6.0
#
#                                                 address
# 0        A50 Tangenziale Ovest di Milano, km 18, Assago
# 1        A50 Tangenziale Ovest di Milano, km 18, Assago
# 2             Viale Milanofiori SDA 6, Assago, MI 20090
# 3                         Piazza degli Incontri, Assago
# 4                                      Via Roma, Assago
# ...                                                 ...
# 6444  Viale Thomas Alva Edison, 452, Sesto San Giovanni
# 6445            Via Marzabotto, 199, Sesto San Giovanni
# 6446                     Via Bilbao, 2, Cologno Monzese
# 6447   Via Michelangelo Buonarroti, 14, Cologno Monzese
# 6448    Via Michelangelo Buonarroti, 2, Cologno Monzese
#
# [6449 rows x 6 columns]

# %%
df=pd.read_csv("C:/Users/pc/Desktop/progetti data management/data-management-project/output_files/record_linkage_index.csv")
df
# Out:
#                                              trip  \
# 0                                       'O Macarò
# 1                       02 Hosteria Contemporanea
# 2                                #gelatamo Milano
# 3                                   01 Curti Food
# 4                                  100 Montaditos
# ...                                           ...
# 6894                           un mon dodi sapori
# 6895                                       Carico
# 6896   theLab - unconventional burger experience®
# 6897                            İstanbul Girasole
# 6898                            Ristorante Ischia
#
#                                                 similar
# 0     [{'score': 100, 'google': "'O Macarò", 'format...
# 1     [{'score': 100, 'google': '02 Hosteria Contemp...
# 2                                                    []
# 3                                                    []
# 4     [{'score': 100, 'google': '100 Montaditos', 'f...
# ...                                                 ...
# 6894  [{'score': 100, 'google': 'Un Mondo di Sapori'...
# 6895                                                 []
# 6896                                                 []
# 6897                                                 []
# 6898  [{'score': 80, 'google': 'RISTORANTE MINA', 'f...
#
# [6899 rows x 2 columns]

# %%
df = df.rename(columns={'trip': 'title'})
df
# Out:
#                                             title  \
# 0                                       'O Macarò
# 1                       02 Hosteria Contemporanea
# 2                                #gelatamo Milano
# 3                                   01 Curti Food
# 4                                  100 Montaditos
# ...                                           ...
# 6894                           un mon dodi sapori
# 6895                                       Carico
# 6896   theLab - unconventional burger experience®
# 6897                            İstanbul Girasole
# 6898                            Ristorante Ischia
#
#                                                 similar
# 0     [{'score': 100, 'google': "'O Macarò", 'format...
# 1     [{'score': 100, 'google': '02 Hosteria Contemp...
# 2                                                    []
# 3                                                    []
# 4     [{'score': 100, 'google': '100 Montaditos', 'f...
# ...                                                 ...
# 6894  [{'score': 100, 'google': 'Un Mondo di Sapori'...
# 6895                                                 []
# 6896                                                 []
# 6897                                                 []
# 6898  [{'score': 80, 'google': 'RISTORANTE MINA', 'f...
#
# [6899 rows x 2 columns]

# %%
#import ast

#def get_google_name(similar):
    #if similar:
        # convert the string representation of list of dicts to an actual list of dicts
       #matches = ast.literal_eval(similar)
        #if matches:
            #return matches[0]['google']
    #return ''

#df['similar'] = df['similar'].apply(get_google_name)
#df = df[['trip', 'similar']]

# %%
df
# Out:
#                                             title  \
# 0                                       'O Macarò
# 1                       02 Hosteria Contemporanea
# 2                                #gelatamo Milano
# 3                                   01 Curti Food
# 4                                  100 Montaditos
# ...                                           ...
# 6894                           un mon dodi sapori
# 6895                                       Carico
# 6896   theLab - unconventional burger experience®
# 6897                            İstanbul Girasole
# 6898                            Ristorante Ischia
#
#                                                 similar
# 0     [{'score': 100, 'google': "'O Macarò", 'format...
# 1     [{'score': 100, 'google': '02 Hosteria Contemp...
# 2                                                    []
# 3                                                    []
# 4     [{'score': 100, 'google': '100 Montaditos', 'f...
# ...                                                 ...
# 6894  [{'score': 100, 'google': 'Un Mondo di Sapori'...
# 6895                                                 []
# 6896                                                 []
# 6897                                                 []
# 6898  [{'score': 80, 'google': 'RISTORANTE MINA', 'f...
#
# [6899 rows x 2 columns]

# %%
overall_trip
# Out:
#         id                                title           r_bubbles  \
# 0        0                   Mabuhay Restaurant  Punteggio 5,0 su 5
# 1        1                        Parea Bistrot  Punteggio 5,0 su 5
# 2        2                            Il Panino  Punteggio 5,0 su 5
# 3        3                 Cantiere Hambirreria  Punteggio 5,0 su 5
# 4        4  BLUE M Milano - Bottega Marchigiana  Punteggio 5,0 su 5
# ...    ...                                  ...                 ...
# 6964  6964             La Buttiga Franco's Room                   ?
# 6965  6965                               Nk Bar                   ?
# 6966  6966                  Caffè Vergnano 1882                   ?
# 6967  6967                               Hekfan                   ?
# 6968  6968              La Puccia Ignorante Xxl                   ?
#
#             r_number                 cook_type expensive  \
# 0     842 recensioni                 Filippina         €
# 1     158 recensioni                         ?         ?
# 2     226 recensioni  Italiana, Cibo di strada         €
# 3     923 recensioni       Italiana, Americana         ?
# 4     158 recensioni                  Italiana         €
# ...              ...                       ...       ...
# 6964               0       Italiana, Americana         ?
# 6965               0                     Pizza         ?
# 6966               0                         ?         ?
# 6967               0                         ?         ?
# 6968               0       Italiana, Fast food         €
#
#                                            address_trip  \
# 0        Bastioni di Porta Volta 9, 20121 Milano Italia
# 1                      Via Vigna 6, 20123 Milano Italia
# 2                   Via Laghetto 7, 20122 Milano Italia
# 3             Corso Garibaldi, 111, 20121 Milano Italia
# 4     Via Lanzone 27 Sant'Ambrogio - Università Catt...
# ...                                                 ...
# 6964           Via Castelbarco, 17, 20136 Milano Italia
# 6965        Via Giuseppe Saragat 6, 20128 Milano Italia
# 6966  Piazza Venticinque Aprile, 10 Eataly Smeraldo,...
# 6967             Via Marco Formentini, 2, Milano Italia
# 6968    Via Filippo Brunelleschi 4, 20146 Milano Italia
#
#                                                 reviews
# 0     [{'bubbles': 'bubble_50', 'title': 'Piacevole ...
# 1     [{'bubbles': 'bubble_50', 'title': 'Locale sex...
# 2     [{'bubbles': 'bubble_50', 'title': 'Da brevett...
# 3     [{'bubbles': 'bubble_50', 'title': 'SUPER!', '...
# 4     [{'bubbles': 'bubble_50', 'title': 'Le Marche ...
# ...                                                 ...
# 6964                                                 []
# 6965                                                 []
# 6966                                                 []
# 6967                                                 []
# 6968                                                 []
#
# [6968 rows x 8 columns]

# %%
google_dataset = google_dataset.rename(columns={'name_google': 'new_column'})

# %%
#pd.merge(overall_trip,df, on="title")
df['title'] = df['title'].str.strip()
overall_trip['title'] = overall_trip['title'].str.strip()
merged_df = pd.merge(overall_trip, df, on='title')
merged_df
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_20436\3626995157.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_trip['title'] = overall_trip['title'].str.strip()
#         id                                title           r_bubbles  \
# 0        0                   Mabuhay Restaurant  Punteggio 5,0 su 5
# 1        1                        Parea Bistrot  Punteggio 5,0 su 5
# 2        2                            Il Panino  Punteggio 5,0 su 5
# 3        3                 Cantiere Hambirreria  Punteggio 5,0 su 5
# 4        4  BLUE M Milano - Bottega Marchigiana  Punteggio 5,0 su 5
# ...    ...                                  ...                 ...
# 8533  6963   Davet Turkish Kebap Pizzeria Grill                   ?
# 8534  6964             La Buttiga Franco's Room                   ?
# 8535  6965                               Nk Bar                   ?
# 8536  6967                               Hekfan                   ?
# 8537  6968              La Puccia Ignorante Xxl                   ?
#
#             r_number                 cook_type expensive  \
# 0     842 recensioni                 Filippina         €
# 1     158 recensioni                         ?         ?
# 2     226 recensioni  Italiana, Cibo di strada         €
# 3     923 recensioni       Italiana, Americana         ?
# 4     158 recensioni                  Italiana         €
# ...              ...                       ...       ...
# 8533               0          Pizza, Fast food         ?
# 8534               0       Italiana, Americana         ?
# 8535               0                     Pizza         ?
# 8536               0                         ?         ?
# 8537               0       Italiana, Fast food         €
#
#                                            address_trip  \
# 0        Bastioni di Porta Volta 9, 20121 Milano Italia
# 1                      Via Vigna 6, 20123 Milano Italia
# 2                   Via Laghetto 7, 20122 Milano Italia
# 3             Corso Garibaldi, 111, 20121 Milano Italia
# 4     Via Lanzone 27 Sant'Ambrogio - Università Catt...
# ...                                                 ...
# 8533   Piazzale Stazione Genova, 2, 20144 Milano Italia
# 8534           Via Castelbarco, 17, 20136 Milano Italia
# 8535        Via Giuseppe Saragat 6, 20128 Milano Italia
# 8536             Via Marco Formentini, 2, Milano Italia
# 8537    Via Filippo Brunelleschi 4, 20146 Milano Italia
#
#                                                 reviews  \
# 0     [{'bubbles': 'bubble_50', 'title': 'Piacevole ...
# 1     [{'bubbles': 'bubble_50', 'title': 'Locale sex...
# 2     [{'bubbles': 'bubble_50', 'title': 'Da brevett...
# 3     [{'bubbles': 'bubble_50', 'title': 'SUPER!', '...
# 4     [{'bubbles': 'bubble_50', 'title': 'Le Marche ...
# ...                                                 ...
# 8533                                                 []
# 8534                                                 []
# 8535                                                 []
# 8536                                                 []
# 8537                                                 []
#
#                                                 similar
# 0     [{'score': 80, 'google': 'Mia Restaurant', 'fo...
# 1     [{'score': 82, 'google': 'Ape Bistrot', 'forma...
# 2                                                    []
# 3                                                    []
# 4     [{'score': 100, 'google': 'BLUE M MILANO - BOT...
# ...                                                 ...
# 8533  [{'score': 86, 'google': 'DAYI TURKISH KEBAP P...
# 8534                                                 []
# 8535                                                 []
# 8536                                                 []
# 8537                                                 []
#
# [8538 rows x 9 columns]

# %%
duplicates = merged_df.duplicated(subset=['title'], keep=False)
ids = merged_df[duplicates]['id']
print(ids)
# Out:
# 118      119
# 119      119
# 120     3501
# 121     3501
# 155      153
#         ...
# 8279    6814
# 8280    6814
# 8281    6814
# 8487    6909
# 8488    6909
# Name: id, Length: 2187, dtype: int64

# %%
merged_df=merged_df.drop_duplicates('id')

# %%
merged_df = merged_df.set_index('id')
merged_df
# Out:
#                                     title           r_bubbles        r_number  \
# id
# 0                      Mabuhay Restaurant  Punteggio 5,0 su 5  842 recensioni
# 1                           Parea Bistrot  Punteggio 5,0 su 5  158 recensioni
# 2                               Il Panino  Punteggio 5,0 su 5  226 recensioni
# 3                    Cantiere Hambirreria  Punteggio 5,0 su 5  923 recensioni
# 4     BLUE M Milano - Bottega Marchigiana  Punteggio 5,0 su 5  158 recensioni
# ...                                   ...                 ...             ...
# 6963   Davet Turkish Kebap Pizzeria Grill                   ?               0
# 6964             La Buttiga Franco's Room                   ?               0
# 6965                               Nk Bar                   ?               0
# 6967                               Hekfan                   ?               0
# 6968              La Puccia Ignorante Xxl                   ?               0
#
#                      cook_type expensive  \
# id
# 0                    Filippina         €
# 1                            ?         ?
# 2     Italiana, Cibo di strada         €
# 3          Italiana, Americana         ?
# 4                     Italiana         €
# ...                        ...       ...
# 6963          Pizza, Fast food         ?
# 6964       Italiana, Americana         ?
# 6965                     Pizza         ?
# 6967                         ?         ?
# 6968       Italiana, Fast food         €
#
#                                            address_trip  \
# id
# 0        Bastioni di Porta Volta 9, 20121 Milano Italia
# 1                      Via Vigna 6, 20123 Milano Italia
# 2                   Via Laghetto 7, 20122 Milano Italia
# 3             Corso Garibaldi, 111, 20121 Milano Italia
# 4     Via Lanzone 27 Sant'Ambrogio - Università Catt...
# ...                                                 ...
# 6963   Piazzale Stazione Genova, 2, 20144 Milano Italia
# 6964           Via Castelbarco, 17, 20136 Milano Italia
# 6965        Via Giuseppe Saragat 6, 20128 Milano Italia
# 6967             Via Marco Formentini, 2, Milano Italia
# 6968    Via Filippo Brunelleschi 4, 20146 Milano Italia
#
#                                                 reviews  \
# id
# 0     [{'bubbles': 'bubble_50', 'title': 'Piacevole ...
# 1     [{'bubbles': 'bubble_50', 'title': 'Locale sex...
# 2     [{'bubbles': 'bubble_50', 'title': 'Da brevett...
# 3     [{'bubbles': 'bubble_50', 'title': 'SUPER!', '...
# 4     [{'bubbles': 'bubble_50', 'title': 'Le Marche ...
# ...                                                 ...
# 6963                                                 []
# 6964                                                 []
# 6965                                                 []
# 6967                                                 []
# 6968                                                 []
#
#                                                 similar
# id
# 0     [{'score': 80, 'google': 'Mia Restaurant', 'fo...
# 1     [{'score': 82, 'google': 'Ape Bistrot', 'forma...
# 2                                                    []
# 3                                                    []
# 4     [{'score': 100, 'google': 'BLUE M MILANO - BOT...
# ...                                                 ...
# 6963  [{'score': 86, 'google': 'DAYI TURKISH KEBAP P...
# 6964                                                 []
# 6965                                                 []
# 6967                                                 []
# 6968                                                 []
#
# [6883 rows x 8 columns]

# %%
import re

# Regular expression pattern to match the relevant information
pattern = r"\{'score': \d+, 'google': '([^']*)', 'formatted_google': '([^']*)'\}"

# Function to extract information from the "similar" column
def extract_similar(similar):
    matches = re.findall(pattern, similar)
    return {match[0]: match[1] for match in matches}

# Apply the function to the "similar" column
merged_df['similar'] = merged_df['similar'].apply(extract_similar)

# %%
import pandas as pd

pd.set_option('display.max_rows', 50)

merged = merged_df.loc[:, ["title", "address_trip", "similar"]]
import pandas as pd
merged
#merged.to_excel('prova.xlsx', index=False)
# Out:
#                                     title  \
# id
# 0                      Mabuhay Restaurant
# 1                           Parea Bistrot
# 2                               Il Panino
# 3                    Cantiere Hambirreria
# 4     BLUE M Milano - Bottega Marchigiana
# ...                                   ...
# 6963   Davet Turkish Kebap Pizzeria Grill
# 6964             La Buttiga Franco's Room
# 6965                               Nk Bar
# 6967                               Hekfan
# 6968              La Puccia Ignorante Xxl
#
#                                            address_trip  \
# id
# 0        Bastioni di Porta Volta 9, 20121 Milano Italia
# 1                      Via Vigna 6, 20123 Milano Italia
# 2                   Via Laghetto 7, 20122 Milano Italia
# 3             Corso Garibaldi, 111, 20121 Milano Italia
# 4     Via Lanzone 27 Sant'Ambrogio - Università Catt...
# ...                                                 ...
# 6963   Piazzale Stazione Genova, 2, 20144 Milano Italia
# 6964           Via Castelbarco, 17, 20136 Milano Italia
# 6965        Via Giuseppe Saragat 6, 20128 Milano Italia
# 6967             Via Marco Formentini, 2, Milano Italia
# 6968    Via Filippo Brunelleschi 4, 20146 Milano Italia
#
#                                                 similar
# id
# 0                   {'Mia Restaurant': 'miarestaurant'}
# 1     {'Ape Bistrot': 'apebistrot', 'Arena Bistrot':...
# 2                                                    {}
# 3                                                    {}
# 4     {'BLUE M MILANO - BOTTEGA MARCHIGIANA': 'bluem...
# ...                                                 ...
# 6963  {'DAYI TURKISH KEBAP PIZZA GRILL': 'dayiturkis...
# 6964                                                 {}
# 6965                                                 {}
# 6967                                                 {}
# 6968                                                 {}
#
# [6883 rows x 3 columns]

# %%
merged['similar'] = merged['similar'].apply(lambda x: list(x.keys()))

# %%
merged['new_column'] = merged['similar'].apply(lambda x: x[0] if len(x) > 0 else None)

# %%
merged.pop('similar')
# Out:
# id
# 0                                        [Mia Restaurant]
# 1                            [Ape Bistrot, Arena Bistrot]
# 2                                                      []
# 3                                                      []
# 4                   [BLUE M MILANO - BOTTEGA MARCHIGIANA]
#                               ...
# 6963    [DAYI TURKISH KEBAP PIZZA GRILL, Turkish Kebap...
# 6964                                                   []
# 6965                                                   []
# 6967                                                   []
# 6968                                                   []
# Name: similar, Length: 6883, dtype: object

# %%
merged
# Out:
#                                     title  \
# id
# 0                      Mabuhay Restaurant
# 1                           Parea Bistrot
# 2                               Il Panino
# 3                    Cantiere Hambirreria
# 4     BLUE M Milano - Bottega Marchigiana
# ...                                   ...
# 6963   Davet Turkish Kebap Pizzeria Grill
# 6964             La Buttiga Franco's Room
# 6965                               Nk Bar
# 6967                               Hekfan
# 6968              La Puccia Ignorante Xxl
#
#                                            address_trip  \
# id
# 0        Bastioni di Porta Volta 9, 20121 Milano Italia
# 1                      Via Vigna 6, 20123 Milano Italia
# 2                   Via Laghetto 7, 20122 Milano Italia
# 3             Corso Garibaldi, 111, 20121 Milano Italia
# 4     Via Lanzone 27 Sant'Ambrogio - Università Catt...
# ...                                                 ...
# 6963   Piazzale Stazione Genova, 2, 20144 Milano Italia
# 6964           Via Castelbarco, 17, 20136 Milano Italia
# 6965        Via Giuseppe Saragat 6, 20128 Milano Italia
# 6967             Via Marco Formentini, 2, Milano Italia
# 6968    Via Filippo Brunelleschi 4, 20146 Milano Italia
#
#                                new_column
# id
# 0                          Mia Restaurant
# 1                             Ape Bistrot
# 2                                    None
# 3                                    None
# 4     BLUE M MILANO - BOTTEGA MARCHIGIANA
# ...                                   ...
# 6963       DAYI TURKISH KEBAP PIZZA GRILL
# 6964                                 None
# 6965                                 None
# 6967                                 None
# 6968                                 None
#
# [6883 rows x 3 columns]

# %%
google_dataset
# Out:
#       Index                      new_column  price_level_google  \
# 0         0                       Autogrill                 2.0
# 1         2        L'angolo del Buongustaio                 NaN
# 2         3     Compagnia Dell'Espresso Srl                 NaN
# 3         4                       Assago 03                 NaN
# 4         5                     Rasoi baget                 NaN
# ...     ...                             ...                 ...
# 6444  22590        Happy Moments Restaurant                 2.0
# 6445  22600    Bar Olimpia Di Gaeta Deborah                 NaN
# 6446  22605               Vinum Et Alia SPA                 NaN
# 6447  22607  Pizzeria Ristorante San Mina 2                 1.0
# 6448  22608                  Bar Buonarroti                 NaN
#
#       rating_google  total_reviews_google  \
# 0               3.5                2501.0
# 1               1.0                   1.0
# 2               NaN                   NaN
# 3               NaN                   NaN
# 4               NaN                   NaN
# ...             ...                   ...
# 6444            4.5                 826.0
# 6445            3.6                  54.0
# 6446            4.0                   2.0
# 6447            4.4                 125.0
# 6448            4.8                   6.0
#
#                                                 address
# 0        A50 Tangenziale Ovest di Milano, km 18, Assago
# 1        A50 Tangenziale Ovest di Milano, km 18, Assago
# 2             Viale Milanofiori SDA 6, Assago, MI 20090
# 3                         Piazza degli Incontri, Assago
# 4                                      Via Roma, Assago
# ...                                                 ...
# 6444  Viale Thomas Alva Edison, 452, Sesto San Giovanni
# 6445            Via Marzabotto, 199, Sesto San Giovanni
# 6446                     Via Bilbao, 2, Cologno Monzese
# 6447   Via Michelangelo Buonarroti, 14, Cologno Monzese
# 6448    Via Michelangelo Buonarroti, 2, Cologno Monzese
#
# [6449 rows x 6 columns]

# %%
merged['new_column'] = merged['new_column'].str.strip()
google_dataset['new_column'] = google_dataset['new_column'].str.strip()
google_and_trip_by_names= pd.merge(merged,google_dataset, on='new_column')
google_and_trip_by_names
# Out:
#                                     title  \
# 0                      Mabuhay Restaurant
# 1                           Parea Bistrot
# 2                             Dei Bistrot
# 3                              Amobistrot
# 4     BLUE M Milano - Bottega Marchigiana
# ...                                   ...
# 4514                Pomodorini e Basilico
# 4515                       Traffic Lights
# 4516                  Trattoria Tricolore
# 4517                      Cleopatra Pizza
# 4518   Davet Turkish Kebap Pizzeria Grill
#
#                                            address_trip  \
# 0        Bastioni di Porta Volta 9, 20121 Milano Italia
# 1                      Via Vigna 6, 20123 Milano Italia
# 2                Via Solferino, 44, 20121 Milano Italia
# 3            Via Gustavo Modena 26, 20129 Milano Italia
# 4     Via Lanzone 27 Sant'Ambrogio - Università Catt...
# ...                                                 ...
# 4514                 Via Savona 75, 20144 Milano Italia
# 4515                     V.le Monza, 112, Milano Italia
# 4516      Via Macedonio Melloni 35, 20129 Milano Italia
# 4517                Via Padova, 29, 20127 Milano Italia
# 4518   Piazzale Stazione Genova, 2, 20144 Milano Italia
#
#                                new_column  Index  price_level_google  \
# 0                          Mia Restaurant   3411                 NaN
# 1                             Ape Bistrot  10103                 NaN
# 2                             Ape Bistrot  10103                 NaN
# 3                             Ape Bistrot  10103                 NaN
# 4     BLUE M MILANO - BOTTEGA MARCHIGIANA   8141                 NaN
# ...                                   ...    ...                 ...
# 4514       Pizzeria pomodorini e basilico   5069                 NaN
# 4515                       Traffic Lights  17766                 1.0
# 4516                  Trattoria Tricolore   9289                 NaN
# 4517                      Cleopatra Pizza  15930                 NaN
# 4518       DAYI TURKISH KEBAP PIZZA GRILL  21145                 NaN
#
#       rating_google  total_reviews_google                            address
# 0               5.0                   1.0        Via Carlo Torre, 43, Milano
# 1               NaN                   NaN      Via Castel Morrone, 5, Milano
# 2               NaN                   NaN      Via Castel Morrone, 5, Milano
# 3               NaN                   NaN      Via Castel Morrone, 5, Milano
# 4               4.7                  87.0            Via Lanzone, 27, Milano
# ...             ...                   ...                                ...
# 4514            3.8                  44.0             Via Savona, 75, Milano
# 4515            4.0                  64.0           Viale Monza, 112, Milano
# 4516            4.6                  32.0  Via Macedonio Melloni, 35, Milano
# 4517            3.8                  32.0             Via Padova, 29, Milano
# 4518            4.2                  81.0      Via Luigi Ornato, 136, Milano
#
# [4519 rows x 8 columns]

# %%
google_and_trip_by_names.to_excel("integration_da_correggere.xlsx", index=False)
